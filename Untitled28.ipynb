# %%
import numpy as np

# Definición de la función de activación (función escalón)
def funcion_activacion(y):
    return 1 if y >= 0 else 0

# Algoritmo de entrenamiento basado en el algoritmo de la imagen
def algoritmo_entrenamiento(X, D, alpha, max_epochs=100):
    n, m = X.shape  # n = número de ejemplos, m = número de características
    W = np.random.uniform(-1, 1, m)  # Inicializar los pesos en valores aleatorios pequeños [-1, 1]
    theta = np.random.uniform(-1, 1)  # Inicializar el umbral aleatoriamente

    for epoch in range(max_epochs):
        total_error = 0
        for i in range(n):
            # Propagar: calcular Y en función de X
            Y = np.dot(X[i], W) - theta
            y_pred = funcion_activacion(Y)

            # Calcular el error
            error = D[i] - y_pred
            total_error += abs(error)

            # Retropropagar: ajustar los pesos y el umbral
            W += alpha * error * X[i]
            theta -= alpha * error

        # Imprimir el error total de cada época
        print(f"Época {epoch+1}, Error Total: {total_error}")

        # Condición de parada si el error total es aceptable (en este caso, cero)
        if total_error == 0:
            print("Entrenamiento completo.")
            break

    return W, theta

# Ejemplo de uso
if __name__ == "__main__":
    # Datos de entrenamiento (X) y salidas deseadas (D)
    X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])  # Entradas para una compuerta XOR
    D = np.array([0, 1, 1, 0])  # Salidas deseadas para compuerta XOR
    alpha = 0.1  # Coeficiente de aprendizaje

    # Entrenar el modelo
    W, theta = algoritmo_entrenamiento(X, D, alpha)

    # Prueba del modelo entrenado
    print("\nPrueba del modelo entrenado:")
    for i in range(len(X)):
        Y = np.dot(X[i], W) - theta
        y_pred = funcion_activacion(Y)
        print(f"Entrada: {X[i]}, Salida esperada: {D[i]}, Salida obtenida: {y_pred}")
    print("Pesos entrenados:", W)
    print("Umbral entrenado:", theta)
# Out:
# Época 1, Error Total: 2
# Época 2, Error Total: 2
# Época 3, Error Total: 1
# Época 4, Error Total: 1
# Época 5, Error Total: 1
# Época 6, Error Total: 2
# Época 7, Error Total: 2
# Época 8, Error Total: 2
# Época 9, Error Total: 3
# Época 10, Error Total: 2
# Época 11, Error Total: 3
# Época 12, Error Total: 2
# Época 13, Error Total: 2
# Época 14, Error Total: 3
# Época 15, Error Total: 2
# Época 16, Error Total: 2
# Época 17, Error Total: 3
# Época 18, Error Total: 4
# Época 19, Error Total: 4
# Época 20, Error Total: 4
# Época 21, Error Total: 4
# Época 22, Error Total: 4
# Época 23, Error Total: 4
# Época 24, Error Total: 4
# Época 25, Error Total: 4
# Época 26, Error Total: 4
# Época 27, Error Total: 4
# Época 28, Error Total: 4
# Época 29, Error Total: 4
# Época 30, Error Total: 4
# Época 31, Error Total: 4
# Época 32, Error Total: 4
# Época 33, Error Total: 4
# Época 34, Error Total: 4
# Época 35, Error Total: 4
# Época 36, Error Total: 4
# Época 37, Error Total: 4
# Época 38, Error Total: 4
# Época 39, Error Total: 4
# Época 40, Error Total: 4
# Época 41, Error Total: 4
# Época 42, Error Total: 4
# Época 43, Error Total: 4
# Época 44, Error Total: 4
# Época 45, Error Total: 4
# Época 46, Error Total: 4
# Época 47, Error Total: 4
# Época 48, Error Total: 4
# Época 49, Error Total: 4
# Época 50, Error Total: 4
# Época 51, Error Total: 4
# Época 52, Error Total: 4
# Época 53, Error Total: 4
# Época 54, Error Total: 4
# Época 55, Error Total: 4
# Época 56, Error Total: 4
# Época 57, Error Total: 4
# Época 58, Error Total: 4
# Época 59, Error Total: 4
# Época 60, Error Total: 4
# Época 61, Error Total: 4
# Época 62, Error Total: 4
# Época 63, Error Total: 4
# Época 64, Error Total: 4
# Época 65, Error Total: 4
# Época 66, Error Total: 4
# Época 67, Error Total: 4
# Época 68, Error Total: 4
# Época 69, Error Total: 4
# Época 70, Error Total: 4
# Época 71, Error Total: 4
# Época 72, Error Total: 4
# Época 73, Error Total: 4
# Época 74, Error Total: 4
# Época 75, Error Total: 4
# Época 76, Error Total: 4
# Época 77, Error Total: 4
# Época 78, Error Total: 4
# Época 79, Error Total: 4
# Época 80, Error Total: 4
# Época 81, Error Total: 4
# Época 82, Error Total: 4
# Época 83, Error Total: 4
# Época 84, Error Total: 4
# Época 85, Error Total: 4
# Época 86, Error Total: 4
# Época 87, Error Total: 4
# Época 88, Error Total: 4
# Época 89, Error Total: 4
# Época 90, Error Total: 4
# Época 91, Error Total: 4
# Época 92, Error Total: 4
# Época 93, Error Total: 4
# Época 94, Error Total: 4
# Época 95, Error Total: 4
# Época 96, Error Total: 4
# Época 97, Error Total: 4
# Época 98, Error Total: 4
# Época 99, Error Total: 4
# Época 100, Error Total: 4
#
# Prueba del modelo entrenado:
# Entrada: [0 0], Salida esperada: 0, Salida obtenida: 1
# Entrada: [0 1], Salida esperada: 1, Salida obtenida: 1
# Entrada: [1 0], Salida esperada: 1, Salida obtenida: 0
# Entrada: [1 1], Salida esperada: 0, Salida obtenida: 0
# Pesos entrenados: [-0.16873593 -0.0832053 ]
# Umbral entrenado: -0.09077246165325864
